# %%
import pandas as pd

# %%
data = pd.read_csv('E:\\data\\fresh_comp_offline\\tianchi_fresh_comp_train_user.csv')

# %%
#print(data)
# Out:
#            user_id    item_id  behavior_type user_geohash  item_category  \
# 0         10001082  285259775              1      97lk14c           4076
# 1         10001082    4368907              1          NaN           5503
# 2         10001082    4368907              1          NaN           5503
# 3         10001082   53616768              1          NaN           9762
# 4         10001082  151466952              1          NaN           5232
# 5         10001082   53616768              4          NaN           9762
# 6         10001082  290088061              1          NaN           5503
# 7         10001082  298397524              1          NaN          10894
# 8         10001082   32104252              1          NaN           6513
# 9         10001082  323339743              1          NaN          10894
# 10        10001082  396795886              1          NaN           2825
# 11        10001082    9947871              1          NaN           2825
# ...

# %%
print(data.shape)
del data['user_geohash']
del data['item_category']
print(data)
# Out:
# (1048575, 6)
#            user_id    item_id  behavior_type           time
# 0         10001082  285259775              1  2014-12-08 18
# 1         10001082    4368907              1  2014-12-12 12
# 2         10001082    4368907              1  2014-12-12 12
# 3         10001082   53616768              1  2014-12-02 15
# 4         10001082  151466952              1  2014-12-12 11
# 5         10001082   53616768              4  2014-12-02 15
# 6         10001082  290088061              1  2014-12-12 12
# 7         10001082  298397524              1  2014-12-12 12
# 8         10001082   32104252              1  2014-12-12 12
# 9         10001082  323339743              1  2014-12-12 12
# 10        10001082  396795886              1  2014-12-12 12
# 11        10001082    9947871              1  2014-11-28 20
# 12        10001082  150720867              1  2014-12-15 08
# 13        10001082  275221686              1  2014-12-03 01
# ...

# %%
time = data['time']
print(time[0].split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0f1b5ac18d38> in <module>()
#       1 time = data['time']
# ----> 2 print(time[0].type)
#
# AttributeError: 'str' object has no attribute 'type'
